# %% [markdown]
# # My fantastics analysis

# %%
import pandas as pd
import matplotlib.pyplot as plt

# %%
df = pd.read_table('DATA/presidents.txt', delimiter=':', header=None)
df
# Out:
#      0           1                         2           3           4  \
# 0    1  Washington                    George  1732-02-22  1799-12-14
# 1    2       Adams                      John  1735-10-30  1826-07-04
# 2    3   Jefferson                    Thomas  1743-04-13  1826-07-04
# 3    4     Madison                     James  1751-03-16  1836-06-28
# 4    5      Monroe                     James  1758-04-28  1831-07-04
# 5    6       Adams               John Quincy  1767-07-11  1848-02-23
# 6    7     Jackson                    Andrew  1767-03-15  1845-06-08
# 7    8   Van Buren                    Martin  1782-12-05  1862-07-24
# 8    9    Harrison             William Henry  1773-02-09  1841-04-04
# 9   10       Tyler                      John  1790-03-29  1862-01-18
# 10  11        Polk                James Knox  1795-11-02  1849-06-15
# 11  12      Taylor                   Zachary  1784-11-24  1850-07-09
# 12  13    Fillmore                   Millard  1800-01-07  1874-03-08
# ...

# %% [markdown]
# Let's find out how many presidents are in each party

# %%
parties = df[9].value_counts()
parties
# Out:
# Republican                 20
# Democratic                 16
# Democratic - Republican     4
# Whig                        4
# no party                    1
# Federalist                  1
# Name: 9, dtype: int64

# %%
parties.plot(kind='barh')
# Out:
# <AxesSubplot:>
